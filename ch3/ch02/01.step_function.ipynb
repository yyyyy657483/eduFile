# %% [markdown]
# ## 신경망 기초 실습
# 계단 함수 구현

# %%
# coding: utf-8

import numpy as np
import matplotlib.pylab as plt

def step_function(x):
    return np.array(x > 0, dtype=int) # 0보다 크면 1출력

X = np.arange(-5.0, 5.0, 0.1)
Y = step_function(X)

plt.plot(X,Y)
plt.ylim(-0.1,1.1)
plt.show()
