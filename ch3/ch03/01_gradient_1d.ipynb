# %% [markdown]
# ## 신경망 학습
# 함수 y = 0.01𝑥^2 + 0.1𝑥 의 x좌표 5에서 수치미분 접선 그리기

# %%
# coding: utf-8
import numpy as np
import matplotlib.pylab as plt

def numerical_diff(f, x):
    h = 1e-4 # 0.0001
    return (f(x + h) - f(x-h)) / (2*h)

def tanget_line(f, x):
    d = numerical_diff(f, x) # 기울기
    print(d)
    y = f(x) - d*x
    return lambda t: d*t + y

# 미분할 함수  그래프 
def function_1(x):
    return 0.01*x**2 + 0.1*x

x = np.arange(0.0, 20.0, 0.1)
y = function_1(x)
plt.xlabel("x")
plt.ylabel("f(x)")

tf = tanget_line(function_1, 5)
y2 = tf(x)

plt.plot(x,y)
plt.plot(x, y2)
plt.show()
# Out:
# 0.1999999999990898
